# %% [markdown]
# # Overview Materi

# %% [markdown]
# Jelaskan perbedaan singkat antara grid, randomized, bayesian search cv dengan optuna menurut pemahamanmu
#
# **Grid Search**: merupakan metode pencarian kombinasi parameter dengan cara mencoba semua kemungkinan yang telah ditentukan. Hasilnya pasti menemukan kombinasi terbaik, tetapi prosesnya membutuhkan waktu lama karena harus menguji setiap kemungkinan satu per satu.
#
# **Randomized Search**: bekerja dengan memilih kombinasi parameter secara acak dari ruang pencarian yang ada. Metode ini jauh lebih cepat dibanding Grid Search, meskipun hasilnya bisa sedikit berbeda setiap kali dijalankan karena sifatnya yang acak.
#
# **Bayesian Search**: menggunakan pendekatan probabilistik untuk memperkirakan kombinasi parameter terbaik berdasarkan hasil percobaan sebelumnya. Cara ini membuat proses pencarian menjadi lebih efisien dan terarah, meskipun penerapannya lebih kompleks.
#
# **Optuna**: adalah library modern yang menggunakan pendekatan mirip Bayesian Optimization, tetapi lebih fleksibel dan cepat. Optuna memiliki fitur pruning untuk menghentikan percobaan yang kurang baik lebih awal, serta menyediakan visualisasi hasil tuning secara otomatis.
# source: https://www.youtube.com/watch?v=t-INgABWULw

# %% [markdown]
# # Import Data & Libraries

# %%
# jalankan hanya sekali
# !pip install optuna -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 8.3 MB/s eta 0:00:00

# %%
# import library yang dibutuhkan di sini
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import optuna
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Data Preprocessing

# %%
# ubah variabel kategorik ke numerik and subsetting peubah
X = df_encoded.drop(['species_versicolor', 'species_virginica'], axis=1)
y = df_encoded[['species_versicolor', 'species_virginica']]

# %%
# ubah variabel kategorik ke numerik
# Remove get_dummies from here
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species_versicolor  \
# 0           5.1          3.5           1.4          0.2               False
# 1           4.9          3.0           1.4          0.2               False
# 2           4.7          3.2           1.3          0.2               False
# 3           4.6          3.1           1.5          0.2               False
# 4           5.0          3.6           1.4          0.2               False
#
#    species_virginica
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False

# %% [markdown]
# # Dataset Splitting

# %%
# split dengan rasio 80:20
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=23, stratify=y
)

# %% [markdown]
# # Base Model Random Forest

# %%
# gunakan random forest classifier
from sklearn.ensemble import RandomForestClassifier
rfr = RandomForestClassifier(random_state=23)
rfr.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=23)

# %%
y_pred = rfr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}")
print(f"Precision: {precision_score(y_test, y_pred, average='weighted'):.3f}")
print(f"Recall: {recall_score(y_test, y_pred, average='weighted'):.3f}")
print(f"F1 Score: {f1_score(y_test, y_pred, average='weighted'):.3f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.000
# Precision: 1.000
# Recall: 1.000
# F1 Score: 1.000
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00        10
#    virginica       1.00      1.00      1.00        10
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# # Optuna

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, accuracy_score

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 1000)
    max_depth = trial.suggest_int('max_depth', 10, 100)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 64)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 64)

    model = RandomForestClassifier(n_estimators=n_estimators,
                                  max_depth=max_depth,
                                  min_samples_split=min_samples_split,
                                  min_samples_leaf=min_samples_leaf,
                                  random_state=42)

    score = cross_val_score(model, X_train, y_train, cv=5, scoring=make_scorer(accuracy_score))

    return score.mean()

# %% [markdown]
# Hyperparameter dapat disesuaikan dengan algoritma yang digunakan. Kali ini kita menggunakan Random Forest sehingga yang dapat kita select adalah *n_estimators, max_depth, min_samples_split,* dan *min_samples_leaf*

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.RandomSampler(seed=42))
# Out:
# [I 2025-10-04 14:01:51,354] A new study created in memory with name: no-name-78797a97-968d-4b23-9634-cf9b39af13ce

# %%
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-10-04 14:01:57,860] Trial 0 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 437, 'max_depth': 96, 'min_samples_split': 48, 'min_samples_leaf': 39}. Best is trial 0 with value: 0.33333333333333337.
# [I 2025-10-04 14:01:59,529] Trial 1 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 240, 'max_depth': 24, 'min_samples_split': 5, 'min_samples_leaf': 56}. Best is trial 0 with value: 0.33333333333333337.
# [I 2025-10-04 14:02:04,959] Trial 2 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 641, 'max_depth': 74, 'min_samples_split': 3, 'min_samples_leaf': 63}. Best is trial 0 with value: 0.33333333333333337.
# [I 2025-10-04 14:02:10,873] Trial 3 finished with value: 0.95 and parameters: {'n_estimators': 850, 'max_depth': 29, 'min_samples_split': 13, 'min_samples_leaf': 12}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:13,821] Trial 4 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 374, 'max_depth': 57, 'min_samples_split': 29, 'min_samples_leaf': 19}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:19,031] Trial 5 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 651, 'max_depth': 22, 'min_samples_split': 20, 'min_samples_leaf': 24}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:22,542] Trial 6 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 510, 'max_depth': 81, 'min_samples_split': 14, 'min_samples_leaf': 33}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:27,855] Trial 7 finished with value: 0.95 and parameters: {'n_estimators': 633, 'max_depth': 14, 'min_samples_split': 40, 'min_samples_leaf': 11}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:29,433] Trial 8 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 158, 'max_depth': 96, 'min_samples_split': 62, 'min_samples_leaf': 52}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:32,050] Trial 9 finished with value: 0.6499999999999999 and parameters: {'n_estimators': 374, 'max_depth': 18, 'min_samples_split': 45, 'min_samples_leaf': 29}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:33,548] Trial 10 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 209, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 59}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:35,843] Trial 11 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 333, 'max_depth': 70, 'min_samples_split': 21, 'min_samples_leaf': 34}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:40,867] Trial 12 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 592, 'max_depth': 26, 'min_samples_split': 63, 'min_samples_leaf': 50}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:47,660] Trial 13 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 946, 'max_depth': 91, 'min_samples_split': 39, 'min_samples_leaf': 59}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:48,913] Trial 14 finished with value: 0.6916666666666667 and parameters: {'n_estimators': 179, 'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 21}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:53,025] Trial 15 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 450, 'max_depth': 34, 'min_samples_split': 54, 'min_samples_leaf': 23}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:55,468] Trial 16 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 353, 'max_depth': 59, 'min_samples_split': 10, 'min_samples_leaf': 52}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:56,654] Trial 17 finished with value: 0.65 and parameters: {'n_estimators': 167, 'max_depth': 99, 'min_samples_split': 50, 'min_samples_leaf': 13}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:02:57,421] Trial 18 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 104, 'max_depth': 84, 'min_samples_split': 46, 'min_samples_leaf': 47}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:03:03,016] Trial 19 finished with value: 0.95 and parameters: {'n_estimators': 794, 'max_depth': 16, 'min_samples_split': 24, 'min_samples_leaf': 8}. Best is trial 3 with value: 0.95.
# [I 2025-10-04 14:03:10,172] Trial 20 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 877, 'max_depth': 66, 'min_samples_split': 22, 'min_samples_leaf': 5}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:03:12,794] Trial 21 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 380, 'max_depth': 39, 'min_samples_split': 47, 'min_samples_leaf': 41}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:03:19,831] Trial 22 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 899, 'max_depth': 52, 'min_samples_split': 9, 'min_samples_leaf': 46}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:03:25,180] Trial 23 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 785, 'max_depth': 61, 'min_samples_split': 50, 'min_samples_leaf': 32}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:03:29,924] Trial 24 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 570, 'max_depth': 48, 'min_samples_split': 3, 'min_samples_leaf': 7}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:03:31,058] Trial 25 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 128, 'max_depth': 67, 'min_samples_split': 21, 'min_samples_leaf': 33}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:03:37,341] Trial 26 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 917, 'max_depth': 32, 'min_samples_split': 27, 'min_samples_leaf': 49}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:03:39,514] Trial 27 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 306, 'max_depth': 17, 'min_samples_split': 20, 'min_samples_leaf': 11}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:03:46,885] Trial 28 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 937, 'max_depth': 83, 'min_samples_split': 41, 'min_samples_leaf': 56}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:03:52,519] Trial 29 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 824, 'max_depth': 26, 'min_samples_split': 58, 'min_samples_leaf': 35}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:03:59,266] Trial 30 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 827, 'max_depth': 91, 'min_samples_split': 22, 'min_samples_leaf': 8}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:01,362] Trial 31 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 305, 'max_depth': 48, 'min_samples_split': 53, 'min_samples_leaf': 56}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:02,152] Trial 32 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 106, 'max_depth': 56, 'min_samples_split': 28, 'min_samples_leaf': 15}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:03,612] Trial 33 finished with value: 0.6166666666666667 and parameters: {'n_estimators': 207, 'max_depth': 40, 'min_samples_split': 61, 'min_samples_leaf': 21}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:08,482] Trial 34 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 567, 'max_depth': 73, 'min_samples_split': 24, 'min_samples_leaf': 63}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:15,194] Trial 35 finished with value: 0.925 and parameters: {'n_estimators': 967, 'max_depth': 32, 'min_samples_split': 33, 'min_samples_leaf': 20}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:17,668] Trial 36 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 356, 'max_depth': 13, 'min_samples_split': 40, 'min_samples_leaf': 33}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:19,089] Trial 37 finished with value: 0.6333333333333334 and parameters: {'n_estimators': 146, 'max_depth': 35, 'min_samples_split': 59, 'min_samples_leaf': 16}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:21,258] Trial 38 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 230, 'max_depth': 54, 'min_samples_split': 64, 'min_samples_leaf': 16}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:26,236] Trial 39 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 705, 'max_depth': 79, 'min_samples_split': 16, 'min_samples_leaf': 47}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:29,217] Trial 40 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 431, 'max_depth': 67, 'min_samples_split': 41, 'min_samples_leaf': 35}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:30,527] Trial 41 finished with value: 0.9416666666666668 and parameters: {'n_estimators': 181, 'max_depth': 86, 'min_samples_split': 22, 'min_samples_leaf': 12}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:32,067] Trial 42 finished with value: 0.7833333333333333 and parameters: {'n_estimators': 136, 'max_depth': 63, 'min_samples_split': 44, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:36,395] Trial 43 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 561, 'max_depth': 30, 'min_samples_split': 42, 'min_samples_leaf': 12}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:41,406] Trial 44 finished with value: 0.6166666666666667 and parameters: {'n_estimators': 722, 'max_depth': 45, 'min_samples_split': 61, 'min_samples_leaf': 9}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:46,107] Trial 45 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 407, 'max_depth': 20, 'min_samples_split': 60, 'min_samples_leaf': 57}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:48,541] Trial 46 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 332, 'max_depth': 70, 'min_samples_split': 53, 'min_samples_leaf': 36}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:52,507] Trial 47 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 577, 'max_depth': 32, 'min_samples_split': 7, 'min_samples_leaf': 58}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:04:59,742] Trial 48 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 911, 'max_depth': 67, 'min_samples_split': 23, 'min_samples_leaf': 23}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:04,943] Trial 49 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 754, 'max_depth': 91, 'min_samples_split': 57, 'min_samples_leaf': 50}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:09,986] Trial 50 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 678, 'max_depth': 17, 'min_samples_split': 12, 'min_samples_leaf': 58}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:14,957] Trial 51 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 646, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 43}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:15,718] Trial 52 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 104, 'max_depth': 24, 'min_samples_split': 36, 'min_samples_leaf': 45}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:20,472] Trial 53 finished with value: 0.6916666666666667 and parameters: {'n_estimators': 687, 'max_depth': 30, 'min_samples_split': 46, 'min_samples_leaf': 16}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:24,162] Trial 54 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 393, 'max_depth': 77, 'min_samples_split': 42, 'min_samples_leaf': 55}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:28,934] Trial 55 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 692, 'max_depth': 61, 'min_samples_split': 7, 'min_samples_leaf': 24}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:31,311] Trial 56 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 338, 'max_depth': 32, 'min_samples_split': 63, 'min_samples_leaf': 26}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:38,480] Trial 57 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 903, 'max_depth': 67, 'min_samples_split': 52, 'min_samples_leaf': 33}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:42,747] Trial 58 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 619, 'max_depth': 54, 'min_samples_split': 14, 'min_samples_leaf': 47}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:45,213] Trial 59 finished with value: 0.9083333333333334 and parameters: {'n_estimators': 352, 'max_depth': 12, 'min_samples_split': 42, 'min_samples_leaf': 12}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:52,731] Trial 60 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 947, 'max_depth': 96, 'min_samples_split': 59, 'min_samples_leaf': 24}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:05:53,547] Trial 61 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 113, 'max_depth': 94, 'min_samples_split': 28, 'min_samples_leaf': 62}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:00,876] Trial 62 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 968, 'max_depth': 87, 'min_samples_split': 20, 'min_samples_leaf': 25}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:07,050] Trial 63 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 866, 'max_depth': 38, 'min_samples_split': 12, 'min_samples_leaf': 36}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:14,566] Trial 64 finished with value: 0.95 and parameters: {'n_estimators': 943, 'max_depth': 73, 'min_samples_split': 37, 'min_samples_leaf': 7}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:19,031] Trial 65 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 654, 'max_depth': 100, 'min_samples_split': 10, 'min_samples_leaf': 34}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:25,768] Trial 66 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 890, 'max_depth': 77, 'min_samples_split': 45, 'min_samples_leaf': 45}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:29,007] Trial 67 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 423, 'max_depth': 36, 'min_samples_split': 52, 'min_samples_leaf': 52}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:35,094] Trial 68 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 881, 'max_depth': 93, 'min_samples_split': 34, 'min_samples_leaf': 33}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:41,593] Trial 69 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 819, 'max_depth': 69, 'min_samples_split': 46, 'min_samples_leaf': 51}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:47,866] Trial 70 finished with value: 0.95 and parameters: {'n_estimators': 901, 'max_depth': 40, 'min_samples_split': 25, 'min_samples_leaf': 7}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:53,095] Trial 71 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 621, 'max_depth': 13, 'min_samples_split': 31, 'min_samples_leaf': 35}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:06:55,651] Trial 72 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 358, 'max_depth': 63, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:01,418] Trial 73 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 841, 'max_depth': 42, 'min_samples_split': 10, 'min_samples_leaf': 34}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:08,032] Trial 74 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 793, 'max_depth': 29, 'min_samples_split': 41, 'min_samples_leaf': 6}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:09,076] Trial 75 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 146, 'max_depth': 58, 'min_samples_split': 36, 'min_samples_leaf': 41}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:14,427] Trial 76 finished with value: 0.7083333333333333 and parameters: {'n_estimators': 754, 'max_depth': 98, 'min_samples_split': 34, 'min_samples_leaf': 21}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:20,925] Trial 77 finished with value: 0.95 and parameters: {'n_estimators': 816, 'max_depth': 34, 'min_samples_split': 29, 'min_samples_leaf': 6}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:21,807] Trial 78 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 122, 'max_depth': 97, 'min_samples_split': 54, 'min_samples_leaf': 45}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:25,115] Trial 79 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 468, 'max_depth': 25, 'min_samples_split': 11, 'min_samples_leaf': 17}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:30,190] Trial 80 finished with value: 0.8583333333333334 and parameters: {'n_estimators': 594, 'max_depth': 75, 'min_samples_split': 43, 'min_samples_leaf': 18}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:36,755] Trial 81 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 960, 'max_depth': 77, 'min_samples_split': 36, 'min_samples_leaf': 40}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:40,575] Trial 82 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 478, 'max_depth': 32, 'min_samples_split': 24, 'min_samples_leaf': 49}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:41,780] Trial 83 finished with value: 0.95 and parameters: {'n_estimators': 112, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:47,815] Trial 84 finished with value: 0.95 and parameters: {'n_estimators': 870, 'max_depth': 74, 'min_samples_split': 31, 'min_samples_leaf': 7}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:51,567] Trial 85 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 542, 'max_depth': 53, 'min_samples_split': 12, 'min_samples_leaf': 28}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:55,772] Trial 86 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 459, 'max_depth': 66, 'min_samples_split': 42, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:07:58,766] Trial 87 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 437, 'max_depth': 66, 'min_samples_split': 33, 'min_samples_leaf': 55}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:03,518] Trial 88 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 693, 'max_depth': 24, 'min_samples_split': 6, 'min_samples_leaf': 42}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:04,631] Trial 89 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 123, 'max_depth': 63, 'min_samples_split': 61, 'min_samples_leaf': 37}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:08,454] Trial 90 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 449, 'max_depth': 68, 'min_samples_split': 30, 'min_samples_leaf': 35}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:15,936] Trial 91 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 948, 'max_depth': 45, 'min_samples_split': 62, 'min_samples_leaf': 58}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:18,703] Trial 92 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 276, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:20,161] Trial 93 finished with value: 0.6916666666666667 and parameters: {'n_estimators': 185, 'max_depth': 72, 'min_samples_split': 6, 'min_samples_leaf': 21}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:26,148] Trial 94 finished with value: 0.65 and parameters: {'n_estimators': 861, 'max_depth': 12, 'min_samples_split': 53, 'min_samples_leaf': 19}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:27,569] Trial 95 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 206, 'max_depth': 73, 'min_samples_split': 41, 'min_samples_leaf': 57}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:33,850] Trial 96 finished with value: 0.95 and parameters: {'n_estimators': 762, 'max_depth': 83, 'min_samples_split': 19, 'min_samples_leaf': 12}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:39,128] Trial 97 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 776, 'max_depth': 83, 'min_samples_split': 64, 'min_samples_leaf': 27}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:42,419] Trial 98 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 435, 'max_depth': 80, 'min_samples_split': 23, 'min_samples_leaf': 60}. Best is trial 20 with value: 0.9583333333333334.
# [I 2025-10-04 14:08:48,997] Trial 99 finished with value: 0.33333333333333337 and parameters: {'n_estimators': 873, 'max_depth': 49, 'min_samples_split': 49, 'min_samples_leaf': 49}. Best is trial 20 with value: 0.9583333333333334.

# %% [markdown]
# it may take a while... so just wait n see ^^
# <br>
# they recommend to set n_trials at 100 cz it seems there's no significant score increase after 100 trials (also inefficient too, you'll have to wait in a quite long time)

# %%
study.best_params
# Out:
# {'n_estimators': 877,
#  'max_depth': 66,
#  'min_samples_split': 22,
#  'min_samples_leaf': 5}

# %% [markdown]
# Berikut hasil hyperparameter tuning dari Optuna

# %%
# cek hasil hyperparameter tuning dari Optuna
best_params = study.best_params

# %% [markdown]
# # Random Forest Using Optuna

# %%
# simpan hasil best hyperparameter tuning ke variabel bari
best_n_estimators = best_params['n_estimators']
best_max_depth = best_params['max_depth']
best_min_samples_split = best_params['min_samples_split']
best_min_samples_leaf = best_params['min_samples_leaf']

# %%
from sklearn.ensemble import RandomForestClassifier
best_model = RandomForestClassifier(
    n_estimators=best_n_estimators,
    max_depth=best_max_depth,
    min_samples_split=best_min_samples_split,
    min_samples_leaf=best_min_samples_leaf,
    random_state=42)

best_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=66, min_samples_leaf=5, min_samples_split=22,
#                        n_estimators=877, random_state=42)

# %%
y_pred = best_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}")
print(f"Precision: {precision_score(y_test, y_pred, average='weighted'):.3f}")
print(f"Recall: {recall_score(y_test, y_pred, average='weighted'):.3f}")
print(f"F1 Score: {f1_score(y_test, y_pred, average='weighted'):.3f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.967
# Precision: 0.955
# Recall: 0.950
# F1 Score: 0.950
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        10
#            1       1.00      0.90      0.95        10
#
#    micro avg       0.95      0.95      0.95        20
#    macro avg       0.95      0.95      0.95        20
# weighted avg       0.95      0.95      0.95        20
#  samples avg       0.63      0.63      0.63        20
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Tidak terdapat kenaikan skor dengan sebelum menggunakan Optuna sebab skor yang dihasilkan melalui base model saja sudah bagus
